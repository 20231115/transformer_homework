# %% [markdown]
# # 从零实现 Transformer 翻译（含多头自注意力、FFN、残差+LayerNorm、位置编码）
# 本节将在不依赖高层封装的情况下，用 PyTorch 实现一个最小可运行的 Transformer，并在一个小型中英平行语料上训练与测试，目的是跑通流程与理解结构。

# %%
import math
import random
from typing import List, Tuple
import torch
import torch.nn as nn
import torch.nn.functional as F

torch.manual_seed(42)

# 强制使用 CUDA
assert torch.cuda.is_available(), "未检测到 CUDA，请在具有 GPU 的环境中运行或安装支持 CUDA 的 PyTorch。"
torch.cuda.set_device(0)
device_torch = torch.device("cuda")
torch.backends.cudnn.benchmark = True

d_model = 128
n_head = 4
d_ff = 256
num_layers = 2
dropout = 0.1
max_len = 64
batch_size = 128
num_epochs = 200
lr = 3e-4

PAD, BOS, EOS, UNK = 0, 1, 2, 3

# %%
class PositionalEncoding(nn.Module):
    def __init__(self, d_model: int, max_len: int, dropout: float = 0.0):
        super().__init__()
        pe = torch.zeros(max_len, d_model)
        position = torch.arange(0, max_len, dtype=torch.float).unsqueeze(1)
        div_term = torch.exp(torch.arange(0, d_model, 2).float() * (-math.log(10000.0) / d_model))
        pe[:, 0::2] = torch.sin(position * div_term)
        pe[:, 1::2] = torch.cos(position * div_term)
        self.register_buffer('pe', pe)
        self.dropout = nn.Dropout(dropout)
    
    def forward(self, x: torch.Tensor):  # x: (B, T, C)
        T = x.size(1)
        x = x + self.pe[:T, :].unsqueeze(0)
        return self.dropout(x)

class MultiHeadAttention(nn.Module):
    def __init__(self, d_model: int, n_head: int, dropout: float = 0.1):
        super().__init__()
        assert d_model % n_head == 0
        self.d_model = d_model
        self.n_head = n_head
        self.head_dim = d_model // n_head
        self.w_q = nn.Linear(d_model, d_model)
        self.w_k = nn.Linear(d_model, d_model)
        self.w_v = nn.Linear(d_model, d_model)
        self.w_o = nn.Linear(d_model, d_model)
        self.dropout = nn.Dropout(dropout)
        self.softmax = nn.Softmax(dim=-1)
    
    def forward(self, q, k, v, attn_mask: torch.Tensor = None):
        B, Tq, C = q.shape
        Tk = k.size(1)
        H, D = self.n_head, self.head_dim
        q = self.w_q(q).view(B, Tq, H, D).permute(0, 2, 1, 3)  # (B,H,Tq,D)
        k = self.w_k(k).view(B, Tk, H, D).permute(0, 2, 1, 3)  # (B,H,Tk,D)
        v = self.w_v(v).view(B, Tk, H, D).permute(0, 2, 1, 3)  # (B,H,Tk,D)
        scores = (q @ k.transpose(-2, -1)) / math.sqrt(D)  # (B,H,Tq,Tk)
        if attn_mask is not None:
            # attn_mask: broadcastable to (B, H, Tq, Tk); 1 for keep, 0 for mask
            scores = scores.masked_fill(attn_mask == 0, float('-inf'))
        attn = self.softmax(scores)
        attn = self.dropout(attn)
        context = attn @ v  # (B,H,Tq,D)
        context = context.permute(0, 2, 1, 3).contiguous().view(B, Tq, C)  # (B,Tq,C)
        out = self.w_o(context)
        return out

class PositionwiseFFN(nn.Module):
    def __init__(self, d_model: int, d_ff: int, dropout: float = 0.1):
        super().__init__()
        self.fc1 = nn.Linear(d_model, d_ff)
        self.fc2 = nn.Linear(d_ff, d_model)
        self.dropout = nn.Dropout(dropout)
        self.act = nn.GELU()
    
    def forward(self, x):
        return self.fc2(self.dropout(self.act(self.fc1(x))))

class ResidualAddNorm(nn.Module):
    def __init__(self, d_model: int, dropout: float = 0.1):
        super().__init__()
        self.dropout = nn.Dropout(dropout)
        self.norm = nn.LayerNorm(d_model)
    
    def forward(self, x, sublayer_out):
        return self.norm(x + self.dropout(sublayer_out))

# %%
class EncoderLayer(nn.Module):
    def __init__(self, d_model, n_head, d_ff, dropout):
        super().__init__()
        self.self_attn = MultiHeadAttention(d_model, n_head, dropout)
        self.ffn = PositionwiseFFN(d_model, d_ff, dropout)
        self.norm1 = ResidualAddNorm(d_model, dropout)
        self.norm2 = ResidualAddNorm(d_model, dropout)
    
    def forward(self, x, src_mask=None):  # x: (B, S, C)
        x2 = self.self_attn(x, x, x, attn_mask=src_mask)
        x = self.norm1(x, x2)
        x2 = self.ffn(x)
        x = self.norm2(x, x2)
        return x

class DecoderLayer(nn.Module):
    def __init__(self, d_model, n_head, d_ff, dropout):
        super().__init__()
        self.self_attn = MultiHeadAttention(d_model, n_head, dropout)
        self.cross_attn = MultiHeadAttention(d_model, n_head, dropout)
        self.ffn = PositionwiseFFN(d_model, d_ff, dropout)
        self.norm1 = ResidualAddNorm(d_model, dropout)
        self.norm2 = ResidualAddNorm(d_model, dropout)
        self.norm3 = ResidualAddNorm(d_model, dropout)
    
    def forward(self, y, memory, tgt_mask=None, memory_mask=None):  # y:(B,T,C)
        y2 = self.self_attn(y, y, y, attn_mask=tgt_mask)
        y = self.norm1(y, y2)
        y2 = self.cross_attn(y, memory, memory, attn_mask=memory_mask)
        y = self.norm2(y, y2)
        y2 = self.ffn(y)
        y = self.norm3(y, y2)
        return y

class Encoder(nn.Module):
    def __init__(self, vocab_size, d_model, n_head, d_ff, num_layers, dropout):
        super().__init__()
        self.emb = nn.Embedding(vocab_size, d_model, padding_idx=PAD)
        self.pos = PositionalEncoding(d_model, max_len, dropout)
        self.layers = nn.ModuleList([EncoderLayer(d_model, n_head, d_ff, dropout) for _ in range(num_layers)])
    
    def forward(self, src, src_mask=None):  # src:(B,S)
        x = self.emb(src) * math.sqrt(self.emb.embedding_dim)
        x = self.pos(x)
        for layer in self.layers:
            x = layer(x, src_mask)
        return x

class Decoder(nn.Module):
    def __init__(self, vocab_size, d_model, n_head, d_ff, num_layers, dropout):
        super().__init__()
        self.emb = nn.Embedding(vocab_size, d_model, padding_idx=PAD)
        self.pos = PositionalEncoding(d_model, max_len, dropout)
        self.layers = nn.ModuleList([DecoderLayer(d_model, n_head, d_ff, dropout) for _ in range(num_layers)])
    
    def forward(self, tgt, memory, tgt_mask=None, memory_mask=None):  # tgt:(B,T)
        y = self.emb(tgt) * math.sqrt(self.emb.embedding_dim)
        y = self.pos(y)
        for layer in self.layers:
            y = layer(y, memory, tgt_mask, memory_mask)
        return y

class Transformer(nn.Module):
    def __init__(self, src_vocab, tgt_vocab, d_model, n_head, d_ff, num_layers, dropout):
        super().__init__()
        self.encoder = Encoder(src_vocab, d_model, n_head, d_ff, num_layers, dropout)
        self.decoder = Decoder(tgt_vocab, d_model, n_head, d_ff, num_layers, dropout)
        self.generator = nn.Linear(d_model, tgt_vocab)
    
    def forward(self, src, tgt_inp, src_mask=None, tgt_mask=None, memory_mask=None):
        memory = self.encoder(src, src_mask)  # (B,S,C)
        out = self.decoder(tgt_inp, memory, tgt_mask, memory_mask)  # (B,T,C)
        logits = self.generator(out)  # (B,T,V)
        return logits

# %%
# 简单分词与词表（英：按空格；中：按字符）
def tokenize_en(s: str) -> List[str]:
    return s.lower().strip().split()
def tokenize_zh(s: str) -> List[str]:
    return list(s.strip())  # 字符级，适合演示


def build_vocab(token_lists: List[List[str]], min_freq: int = 1):
    from collections import Counter
    counter = Counter()
    for tokens in token_lists:
        counter.update(tokens)
    itos = ["<pad>", "<bos>", "<eos>", "<unk>"]
    for tok, freq in counter.items():
        if freq >= min_freq and tok not in itos:
            itos.append(tok)
    stoi = {tok: i for i, tok in enumerate(itos)}
    return stoi, itos

def encode(tokens: List[str], stoi: dict, add_bos: bool, add_eos: bool, max_len: int):
    ids = []
    if add_bos:
        ids.append(BOS)
    for t in tokens:
        ids.append(stoi.get(t, UNK))
        if len(ids) >= max_len - (1 if add_eos else 0):
            break
    if add_eos:
        ids.append(EOS)
    return ids

def pad_to_len(ids: List[int], max_len: int, pad_id: int = PAD):
    return ids + [pad_id] * (max_len - len(ids))

def decode(ids: List[int], itos: List[str]):
    toks = []
    for i in ids:
        if i in (PAD, BOS, EOS):
            continue
        toks.append(itos[i] if i < len(itos) else "<unk>")
    return toks

# %%
# 从 data/test.csv 读取并行语料（英->中），自动识别列名
from pathlib import Path
import pandas as pd

data_dir = Path.cwd() / "data"
csv_path = data_dir / "test.csv"

def load_pairs_from_csv(p: Path):
    if not p.exists():
        raise FileNotFoundError(f"未找到数据文件: {p}")
    df = pd.read_csv(p, encoding="utf-8", dtype=str)  # 读为字符串，避免 NaN
    # 统一列名为小写，便于匹配
    df.columns = [str(c).strip().lower() for c in df.columns]
    candidates = [
        ("en", "zh"),
        ("english", "chinese"),
        ("source", "target"),
        ("src", "tgt"),
        ("text_en", "text_zh"),
        ("eng", "chn"),
    ]
    col_en = col_zh = None
    for a, b in candidates:
        if a in df.columns and b in df.columns:
            col_en, col_zh = a, b
            break
    if col_en is None or col_zh is None:
        if len(df.columns) >= 2:
            col_en, col_zh = df.columns[:2]
            print(f"未匹配到常见列名，默认使用前两列：{col_en}, {col_zh}")
        else:
            raise ValueError("CSV 至少需要两列（英文、中文）")
    en_series = df[col_en].fillna("").astype(str).str.strip()
    zh_series = df[col_zh].fillna("").astype(str).str.strip()
    mask = (en_series != "") & (zh_series != "")
    en_list = en_series[mask].tolist()
    zh_list = zh_series[mask].tolist()
    return list(zip(en_list, zh_list)), (col_en, col_zh), int(mask.sum())

pairs, used_cols, n_rows = load_pairs_from_csv(csv_path)
print(f"已从 {csv_path} 读取 {n_rows} 对句子，列: {used_cols}")

# 构建词表
src_tokens_list = [tokenize_en(s) for s, _ in pairs]
tgt_tokens_list = [tokenize_zh(t) for _, t in pairs]
src_stoi, src_itos = build_vocab(src_tokens_list)
tgt_stoi, tgt_itos = build_vocab(tgt_tokens_list)

src_vocab_size = len(src_itos)
tgt_vocab_size = len(tgt_itos)
src_vocab_size, tgt_vocab_size, len(pairs)

# 数据集 70% 训练 / 30% 测试 划分
all_pairs = pairs
indices = list(range(len(all_pairs)))
random.shuffle(indices)
split = int(0.7 * len(indices))
train_indices = indices[:split]
test_indices = indices[split:]
train_pairs = [all_pairs[i] for i in train_indices]
test_pairs = [all_pairs[i] for i in test_indices]
print(f"数据集划分: 训练 {len(train_pairs)} 对, 测试 {len(test_pairs)} 对 (总计 {len(all_pairs)})")
# Out:
# 已从 d:\xry\yanjiusheng\1\DAMOXING\lab1\t5\data\test.csv 读取 8549 对句子，列: ('en', 'zh')
# 数据集划分: 训练 5984 对, 测试 2565 对 (总计 8549)
# 数据集划分: 训练 5984 对, 测试 2565 对 (总计 8549)

# %%
# 批处理与掩码
def make_batch(pairs: List[Tuple[str, str]], batch_size: int, shuffle: bool = True):
    idxs = list(range(len(pairs)))
    if shuffle:
        random.shuffle(idxs)
    for i in range(0, len(idxs), batch_size):
        b = [pairs[j] for j in idxs[i:i+batch_size]]
        src_batch, tgt_inp_batch, tgt_out_batch = [], [], []
        for s, t in b:
            src_ids = encode(tokenize_en(s), src_stoi, add_bos=False, add_eos=True, max_len=max_len)
            tgt_ids = encode(tokenize_zh(t), tgt_stoi, add_bos=True, add_eos=True, max_len=max_len)
            # teacher forcing: 输入为 <bos> y1 ... y_{n-1}，输出为 y1 ... y_n <eos>
            tgt_inp = tgt_ids[:-1]
            tgt_out = tgt_ids[1:]
            src_batch.append(pad_to_len(src_ids, max_len))
            tgt_inp_batch.append(pad_to_len(tgt_inp, max_len))
            tgt_out_batch.append(pad_to_len(tgt_out, max_len))
        yield (
            torch.tensor(src_batch, dtype=torch.long, device=device_torch),
            torch.tensor(tgt_inp_batch, dtype=torch.long, device=device_torch),
            torch.tensor(tgt_out_batch, dtype=torch.long, device=device_torch),
        )

def subsequent_mask(sz: int):
    # (1, 1, T, T) 上三角为 -inf 或 0 的布尔版，这里用 1/0 表达 keep/mask
    mask = torch.tril(torch.ones((sz, sz), dtype=torch.uint8, device=device_torch))
    return mask.view(1, 1, sz, sz)

def padding_mask(batch_ids: torch.Tensor, pad_id: int = PAD):
    # (B, T) -> (B, 1, 1, T) 1/0
    mask = (batch_ids != pad_id).unsqueeze(1).unsqueeze(1)
    return mask

def combine_masks(*masks):
    # 所有 mask 按与逻辑合并（1 保留，0 屏蔽）
    m = None
    for x in masks:
        if x is None:
            continue
        m = x if m is None else (m & x)
    return m

# %%
# 组网、损失与优化器
from pathlib import Path

model = Transformer(src_vocab_size, tgt_vocab_size, d_model, n_head, d_ff, num_layers, dropout).to(device_torch)
criterion = nn.CrossEntropyLoss(ignore_index=PAD)

# 参数统计
total_params = sum(p.numel() for p in model.parameters())
trainable_params = sum(p.numel() for p in model.parameters() if p.requires_grad)
print(f"参数总数: {total_params:,} | 可训练参数: {trainable_params:,} (~{trainable_params*4/1024/1024:.2f} MB, fp32)")

# 优化器：AdamW
weight_decay = 1e-4
optimizer = torch.optim.AdamW(model.parameters(), lr=lr, betas=(0.9, 0.98), eps=1e-8, weight_decay=weight_decay)

# 动态学习率配置
schedule_mode = 'warmup_cosine'  # 可选: 'warmup_cosine' | 'none'
use_scheduler = schedule_mode != 'none'
steps_per_epoch = (len(train_pairs) + batch_size - 1) // batch_size
total_steps = max(1, num_epochs * steps_per_epoch)
warmup_ratio = 0.06
warmup_steps = max(1, int(total_steps * warmup_ratio))
print(f"steps/epoch={steps_per_epoch}, total_steps={total_steps}, warmup_steps={warmup_steps}, mode={schedule_mode}")

def lr_lambda(current_step: int):
    if not use_scheduler:
        return 1.0
    current_step = max(1, current_step)
    if current_step <= warmup_steps:
        return float(current_step) / float(warmup_steps)
    progress = (current_step - warmup_steps) / float(max(1, total_steps - warmup_steps))
    return 0.5 * (1.0 + math.cos(math.pi * progress))  # cosine

scheduler = torch.optim.lr_scheduler.LambdaLR(optimizer, lr_lambda=lr_lambda) if use_scheduler else None
global_step = 0  # 全局 step 计数

def get_lr(optim):
    return optim.param_groups[0]['lr']

def set_lr(optim, new_lr: float):
    for pg in optim.param_groups:
        pg['lr'] = new_lr
    print(f"[set_lr] 学习率已手动更新为 {new_lr:.6f}")

def set_schedule_mode(mode: str):
    global schedule_mode, use_scheduler, scheduler
    assert mode in ('warmup_cosine','none')
    schedule_mode = mode
    use_scheduler = (mode != 'none')
    if use_scheduler:
        print(f"[set_schedule_mode] 切换到 {mode}，重新初始化调度器。")
        # 重新创建调度器（保留当前步数 global_step 的比例影响）
        scheduler = torch.optim.lr_scheduler.LambdaLR(optimizer, lr_lambda=lr_lambda)
    else:
        scheduler = None
        print(f"[set_schedule_mode] 调度关闭，学习率保持固定 {get_lr(optimizer):.6f}")

# 训练 / 测试 历史记录
train_losses = []
test_losses = []
lrs = []

# 检查点保存/加载
ckpt_dir = Path.cwd() / "checkpoints"
ckpt_dir.mkdir(parents=True, exist_ok=True)
last_ckpt = ckpt_dir / "last.pt"
best_ckpt = ckpt_dir / "best.pt"
best_loss = float('inf')

def save_checkpoint(path: Path, epoch: int, model: nn.Module, optimizer, best_loss: float):
    state = {
        'epoch': epoch,
        'model': model.state_dict(),
        'optimizer': optimizer.state_dict(),
        'best_loss': best_loss,
        'global_step': global_step,
        'config': {
            'd_model': d_model, 'n_head': n_head, 'd_ff': d_ff, 'num_layers': num_layers,
            'dropout': dropout, 'max_len': max_len, 'src_vocab_size': src_vocab_size, 'tgt_vocab_size': tgt_vocab_size,
            'schedule_mode': schedule_mode, 'warmup_steps': warmup_steps, 'total_steps': total_steps, 'lr': lr
        }
    }
    torch.save(state, path)

def load_checkpoint(path: Path, model: nn.Module, optimizer=None, map_location=device_torch):
    ckpt = torch.load(path, map_location=map_location)
    model.load_state_dict(ckpt['model'])
    if optimizer is not None and 'optimizer' in ckpt:
        optimizer.load_state_dict(ckpt['optimizer'])
    print(f"[load_checkpoint] 恢复 epoch={ckpt.get('epoch')} best_loss={ckpt.get('best_loss')} global_step={ckpt.get('global_step')}")
    return ckpt.get('epoch', None), ckpt.get('best_loss', None)

def train_one_epoch(dataset):
    global global_step
    model.train()
    total_loss = 0.0
    steps = 0
    for src, tgt_inp, tgt_out in make_batch(dataset, batch_size, shuffle=True):
        B, S = src.size()
        T = tgt_inp.size(1)
        src_mask = padding_mask(src)  # (B,1,1,S)
        tgt_pad_mask = padding_mask(tgt_inp)  # (B,1,1,T)
        tgt_sub_mask = subsequent_mask(T)  # (1,1,T,T)
        tgt_mask = combine_masks(tgt_pad_mask, tgt_sub_mask)  # (B,1,T,T)
        mem_mask = src_mask  # (B,1,1,S) 广播到 (B,1,T,S)
        logits = model(src, tgt_inp, src_mask=src_mask, tgt_mask=tgt_mask, memory_mask=mem_mask)  # (B,T,V)
        loss = criterion(logits.view(B*T, -1), tgt_out.view(B*T))
        optimizer.zero_grad()
        loss.backward()
        torch.nn.utils.clip_grad_norm_(model.parameters(), max_norm=1.0)
        optimizer.step()
        # 调度器动态更新
        global_step += 1
        if scheduler is not None:
            scheduler.step()
        total_loss += loss.item()
        steps += 1
        lrs.append(get_lr(optimizer))
    return total_loss / max(steps, 1)

@torch.no_grad()
def evaluate(dataset):
    model.eval()
    total_loss = 0.0
    steps = 0
    for src, tgt_inp, tgt_out in make_batch(dataset, batch_size, shuffle=False):
        B, S = src.size()
        T = tgt_inp.size(1)
        src_mask = padding_mask(src)
        tgt_pad_mask = padding_mask(tgt_inp)
        tgt_sub_mask = subsequent_mask(T)
        tgt_mask = combine_masks(tgt_pad_mask, tgt_sub_mask)
        mem_mask = src_mask
        logits = model(src, tgt_inp, src_mask=src_mask, tgt_mask=tgt_mask, memory_mask=mem_mask)
        loss = criterion(logits.view(B*T, -1), tgt_out.view(B*T))
        total_loss += loss.item()
        steps += 1
    return total_loss / max(steps, 1)
# Out:
# 参数总数: 3,684,411 | 可训练参数: 3,684,411 (~14.05 MB, fp32)
# steps/epoch=47, total_steps=9400, warmup_steps=564, mode=warmup_cosine

# %%
# 简单贪心解码
@torch.no_grad()
def greedy_decode(model, src_sentence: str, max_new_tokens: int = 40):
    model.eval()
    src = torch.tensor([pad_to_len(encode(tokenize_en(src_sentence), src_stoi, add_bos=False, add_eos=True, max_len=max_len), max_len)], device=device_torch)
    src_mask = padding_mask(src)  # (1,1,1,S)
    memory = model.encoder(src, src_mask)  # (1,S,C)
    ys = torch.tensor([[BOS]], device=device_torch)  # (1,1)
    for _ in range(max_new_tokens):
        tgt_mask = combine_masks(padding_mask(ys), subsequent_mask(ys.size(1)))  # (1,1,T,T)
        out = model.decoder(ys, memory, tgt_mask, src_mask)  # (1,T,C)
        logits = model.generator(out[:, -1:, :])  # (1,1,V)
        next_token = logits.argmax(dim=-1)[:, -1]  # (1,)
        ys = torch.cat([ys, next_token.unsqueeze(1)], dim=1)  # (1,T+1)
        if next_token.item() == EOS:
            break
    pred_ids = ys[0].tolist()[1:]  # 去掉 BOS
    pred_tokens = decode(pred_ids, tgt_itos)
    return "".join(pred_tokens)  # 中文字符级，直接拼接

# %%
# 训练并测试（可动态调节学习率；最优依据测试集 loss）
for epoch in range(1, num_epochs + 1):
    train_loss = train_one_epoch(train_pairs)
    test_loss = evaluate(test_pairs)
    train_losses.append(train_loss)
    test_losses.append(test_loss)
    # 保存最新检查点
    save_checkpoint(last_ckpt, epoch, model, optimizer, best_loss)
    # 保存最优（测试集）检查点
    if test_loss < best_loss:
        best_loss = test_loss
        save_checkpoint(best_ckpt, epoch, model, optimizer, best_loss)
        print(f"epoch {epoch:02d} | train {train_loss:.4f} | test {test_loss:.4f} | lr {lrs[-1]:.2e}  -> 保存最优模型: {best_ckpt}")
    else:
        print(f"epoch {epoch:02d} | train {train_loss:.4f} | test {test_loss:.4f} | lr {lrs[-1]:.2e}")
    # 示例：可在此根据 epoch 动态切换策略或手动调 lr（可注释/解注释）
    # if epoch == 10:
    #     set_schedule_mode('none')  # 切到固定学习率
    # if epoch == 20:
    #     set_lr(optimizer, 1e-4)  # 直接把学习率改为 1e-4
# Out:
# epoch 01 | train 8.1231 | test 8.0579 | lr 2.50e-05  -> 保存最优模型: d:\xry\yanjiusheng\1\DAMOXING\lab1\t5\checkpoints\best.pt
# epoch 02 | train 7.9022 | test 7.6239 | lr 5.00e-05  -> 保存最优模型: d:\xry\yanjiusheng\1\DAMOXING\lab1\t5\checkpoints\best.pt
# epoch 02 | train 7.9022 | test 7.6239 | lr 5.00e-05  -> 保存最优模型: d:\xry\yanjiusheng\1\DAMOXING\lab1\t5\checkpoints\best.pt
# epoch 03 | train 7.2897 | test 6.9724 | lr 7.50e-05  -> 保存最优模型: d:\xry\yanjiusheng\1\DAMOXING\lab1\t5\checkpoints\best.pt
# epoch 03 | train 7.2897 | test 6.9724 | lr 7.50e-05  -> 保存最优模型: d:\xry\yanjiusheng\1\DAMOXING\lab1\t5\checkpoints\best.pt
# epoch 04 | train 6.7605 | test 6.5235 | lr 1.00e-04  -> 保存最优模型: d:\xry\yanjiusheng\1\DAMOXING\lab1\t5\checkpoints\best.pt
# epoch 04 | train 6.7605 | test 6.5235 | lr 1.00e-04  -> 保存最优模型: d:\xry\yanjiusheng\1\DAMOXING\lab1\t5\checkpoints\best.pt
# epoch 05 | train 6.3512 | test 6.1696 | lr 1.25e-04  -> 保存最优模型: d:\xry\yanjiusheng\1\DAMOXING\lab1\t5\checkpoints\best.pt
# epoch 05 | train 6.3512 | test 6.1696 | lr 1.25e-04  -> 保存最优模型: d:\xry\yanjiusheng\1\DAMOXING\lab1\t5\checkpoints\best.pt
# epoch 06 | train 6.0537 | test 5.9423 | lr 1.50e-04  -> 保存最优模型: d:\xry\yanjiusheng\1\DAMOXING\lab1\t5\checkpoints\best.pt
# epoch 06 | train 6.0537 | test 5.9423 | lr 1.50e-04  -> 保存最优模型: d:\xry\yanjiusheng\1\DAMOXING\lab1\t5\checkpoints\best.pt
# epoch 07 | train 5.8698 | test 5.8020 | lr 1.75e-04  -> 保存最优模型: d:\xry\yanjiusheng\1\DAMOXING\lab1\t5\checkpoints\best.pt
# epoch 07 | train 5.8698 | test 5.8020 | lr 1.75e-04  -> 保存最优模型: d:\xry\yanjiusheng\1\DAMOXING\lab1\t5\checkpoints\best.pt
# epoch 08 | train 5.7373 | test 5.6756 | lr 2.00e-04  -> 保存最优模型: d:\xry\yanjiusheng\1\DAMOXING\lab1\t5\checkpoints\best.pt
# epoch 08 | train 5.7373 | test 5.6756 | lr 2.00e-04  -> 保存最优模型: d:\xry\yanjiusheng\1\DAMOXING\lab1\t5\checkpoints\best.pt
# epoch 09 | train 5.6004 | test 5.5333 | lr 2.25e-04  -> 保存最优模型: d:\xry\yanjiusheng\1\DAMOXING\lab1\t5\checkpoints\best.pt
# epoch 09 | train 5.6004 | test 5.5333 | lr 2.25e-04  -> 保存最优模型: d:\xry\yanjiusheng\1\DAMOXING\lab1\t5\checkpoints\best.pt
# epoch 10 | train 5.4548 | test 5.3961 | lr 2.50e-04  -> 保存最优模型: d:\xry\yanjiusheng\1\DAMOXING\lab1\t5\checkpoints\best.pt
# epoch 10 | train 5.4548 | test 5.3961 | lr 2.50e-04  -> 保存最优模型: d:\xry\yanjiusheng\1\DAMOXING\lab1\t5\checkpoints\best.pt
# epoch 11 | train 5.3137 | test 5.2698 | lr 2.75e-04  -> 保存最优模型: d:\xry\yanjiusheng\1\DAMOXING\lab1\t5\checkpoints\best.pt
# epoch 11 | train 5.3137 | test 5.2698 | lr 2.75e-04  -> 保存最优模型: d:\xry\yanjiusheng\1\DAMOXING\lab1\t5\checkpoints\best.pt
# epoch 12 | train 5.1772 | test 5.1500 | lr 3.00e-04  -> 保存最优模型: d:\xry\yanjiusheng\1\DAMOXING\lab1\t5\checkpoints\best.pt
# epoch 12 | train 5.1772 | test 5.1500 | lr 3.00e-04  -> 保存最优模型: d:\xry\yanjiusheng\1\DAMOXING\lab1\t5\checkpoints\best.pt
# epoch 13 | train 5.0520 | test 5.0431 | lr 3.00e-04  -> 保存最优模型: d:\xry\yanjiusheng\1\DAMOXING\lab1\t5\checkpoints\best.pt
# epoch 13 | train 5.0520 | test 5.0431 | lr 3.00e-04  -> 保存最优模型: d:\xry\yanjiusheng\1\DAMOXING\lab1\t5\checkpoints\best.pt
# epoch 14 | train 4.9418 | test 4.9554 | lr 3.00e-04  -> 保存最优模型: d:\xry\yanjiusheng\1\DAMOXING\lab1\t5\checkpoints\best.pt
# epoch 14 | train 4.9418 | test 4.9554 | lr 3.00e-04  -> 保存最优模型: d:\xry\yanjiusheng\1\DAMOXING\lab1\t5\checkpoints\best.pt
# epoch 15 | train 4.8406 | test 4.8812 | lr 3.00e-04  -> 保存最优模型: d:\xry\yanjiusheng\1\DAMOXING\lab1\t5\checkpoints\best.pt
# epoch 15 | train 4.8406 | test 4.8812 | lr 3.00e-04  -> 保存最优模型: d:\xry\yanjiusheng\1\DAMOXING\lab1\t5\checkpoints\best.pt
# epoch 16 | train 4.7529 | test 4.8138 | lr 3.00e-04  -> 保存最优模型: d:\xry\yanjiusheng\1\DAMOXING\lab1\t5\checkpoints\best.pt
# epoch 16 | train 4.7529 | test 4.8138 | lr 3.00e-04  -> 保存最优模型: d:\xry\yanjiusheng\1\DAMOXING\lab1\t5\checkpoints\best.pt
# epoch 17 | train 4.6781 | test 4.7573 | lr 2.99e-04  -> 保存最优模型: d:\xry\yanjiusheng\1\DAMOXING\lab1\t5\checkpoints\best.pt
# epoch 17 | train 4.6781 | test 4.7573 | lr 2.99e-04  -> 保存最优模型: d:\xry\yanjiusheng\1\DAMOXING\lab1\t5\checkpoints\best.pt
# epoch 18 | train 4.6074 | test 4.7058 | lr 2.99e-04  -> 保存最优模型: d:\xry\yanjiusheng\1\DAMOXING\lab1\t5\checkpoints\best.pt
# epoch 18 | train 4.6074 | test 4.7058 | lr 2.99e-04  -> 保存最优模型: d:\xry\yanjiusheng\1\DAMOXING\lab1\t5\checkpoints\best.pt
# epoch 19 | train 4.5456 | test 4.6618 | lr 2.99e-04  -> 保存最优模型: d:\xry\yanjiusheng\1\DAMOXING\lab1\t5\checkpoints\best.pt
# epoch 19 | train 4.5456 | test 4.6618 | lr 2.99e-04  -> 保存最优模型: d:\xry\yanjiusheng\1\DAMOXING\lab1\t5\checkpoints\best.pt
# epoch 20 | train 4.4870 | test 4.6184 | lr 2.99e-04  -> 保存最优模型: d:\xry\yanjiusheng\1\DAMOXING\lab1\t5\checkpoints\best.pt
# epoch 20 | train 4.4870 | test 4.6184 | lr 2.99e-04  -> 保存最优模型: d:\xry\yanjiusheng\1\DAMOXING\lab1\t5\checkpoints\best.pt
# epoch 21 | train 4.4338 | test 4.5875 | lr 2.98e-04  -> 保存最优模型: d:\xry\yanjiusheng\1\DAMOXING\lab1\t5\checkpoints\best.pt
# epoch 21 | train 4.4338 | test 4.5875 | lr 2.98e-04  -> 保存最优模型: d:\xry\yanjiusheng\1\DAMOXING\lab1\t5\checkpoints\best.pt
# epoch 22 | train 4.3859 | test 4.5587 | lr 2.98e-04  -> 保存最优模型: d:\xry\yanjiusheng\1\DAMOXING\lab1\t5\checkpoints\best.pt
# epoch 22 | train 4.3859 | test 4.5587 | lr 2.98e-04  -> 保存最优模型: d:\xry\yanjiusheng\1\DAMOXING\lab1\t5\checkpoints\best.pt
# epoch 23 | train 4.3383 | test 4.5303 | lr 2.97e-04  -> 保存最优模型: d:\xry\yanjiusheng\1\DAMOXING\lab1\t5\checkpoints\best.pt
# epoch 23 | train 4.3383 | test 4.5303 | lr 2.97e-04  -> 保存最优模型: d:\xry\yanjiusheng\1\DAMOXING\lab1\t5\checkpoints\best.pt
# epoch 24 | train 4.2954 | test 4.5054 | lr 2.97e-04  -> 保存最优模型: d:\xry\yanjiusheng\1\DAMOXING\lab1\t5\checkpoints\best.pt
# epoch 24 | train 4.2954 | test 4.5054 | lr 2.97e-04  -> 保存最优模型: d:\xry\yanjiusheng\1\DAMOXING\lab1\t5\checkpoints\best.pt
# epoch 25 | train 4.2558 | test 4.4855 | lr 2.96e-04  -> 保存最优模型: d:\xry\yanjiusheng\1\DAMOXING\lab1\t5\checkpoints\best.pt
# epoch 25 | train 4.2558 | test 4.4855 | lr 2.96e-04  -> 保存最优模型: d:\xry\yanjiusheng\1\DAMOXING\lab1\t5\checkpoints\best.pt
# epoch 26 | train 4.2199 | test 4.4635 | lr 2.96e-04  -> 保存最优模型: d:\xry\yanjiusheng\1\DAMOXING\lab1\t5\checkpoints\best.pt
# epoch 26 | train 4.2199 | test 4.4635 | lr 2.96e-04  -> 保存最优模型: d:\xry\yanjiusheng\1\DAMOXING\lab1\t5\checkpoints\best.pt
# epoch 27 | train 4.1851 | test 4.4471 | lr 2.95e-04  -> 保存最优模型: d:\xry\yanjiusheng\1\DAMOXING\lab1\t5\checkpoints\best.pt
# epoch 27 | train 4.1851 | test 4.4471 | lr 2.95e-04  -> 保存最优模型: d:\xry\yanjiusheng\1\DAMOXING\lab1\t5\checkpoints\best.pt
# epoch 28 | train 4.1514 | test 4.4293 | lr 2.95e-04  -> 保存最优模型: d:\xry\yanjiusheng\1\DAMOXING\lab1\t5\checkpoints\best.pt
# epoch 28 | train 4.1514 | test 4.4293 | lr 2.95e-04  -> 保存最优模型: d:\xry\yanjiusheng\1\DAMOXING\lab1\t5\checkpoints\best.pt
# epoch 29 | train 4.1208 | test 4.4172 | lr 2.94e-04  -> 保存最优模型: d:\xry\yanjiusheng\1\DAMOXING\lab1\t5\checkpoints\best.pt
# epoch 29 | train 4.1208 | test 4.4172 | lr 2.94e-04  -> 保存最优模型: d:\xry\yanjiusheng\1\DAMOXING\lab1\t5\checkpoints\best.pt
# epoch 30 | train 4.0889 | test 4.3984 | lr 2.93e-04  -> 保存最优模型: d:\xry\yanjiusheng\1\DAMOXING\lab1\t5\checkpoints\best.pt
# epoch 30 | train 4.0889 | test 4.3984 | lr 2.93e-04  -> 保存最优模型: d:\xry\yanjiusheng\1\DAMOXING\lab1\t5\checkpoints\best.pt
# epoch 31 | train 4.0593 | test 4.3890 | lr 2.93e-04  -> 保存最优模型: d:\xry\yanjiusheng\1\DAMOXING\lab1\t5\checkpoints\best.pt
# epoch 31 | train 4.0593 | test 4.3890 | lr 2.93e-04  -> 保存最优模型: d:\xry\yanjiusheng\1\DAMOXING\lab1\t5\checkpoints\best.pt
# epoch 32 | train 4.0332 | test 4.3760 | lr 2.92e-04  -> 保存最优模型: d:\xry\yanjiusheng\1\DAMOXING\lab1\t5\checkpoints\best.pt
# epoch 32 | train 4.0332 | test 4.3760 | lr 2.92e-04  -> 保存最优模型: d:\xry\yanjiusheng\1\DAMOXING\lab1\t5\checkpoints\best.pt
# epoch 33 | train 4.0070 | test 4.3670 | lr 2.91e-04  -> 保存最优模型: d:\xry\yanjiusheng\1\DAMOXING\lab1\t5\checkpoints\best.pt
# epoch 33 | train 4.0070 | test 4.3670 | lr 2.91e-04  -> 保存最优模型: d:\xry\yanjiusheng\1\DAMOXING\lab1\t5\checkpoints\best.pt
# epoch 34 | train 3.9797 | test 4.3579 | lr 2.90e-04  -> 保存最优模型: d:\xry\yanjiusheng\1\DAMOXING\lab1\t5\checkpoints\best.pt
# epoch 34 | train 3.9797 | test 4.3579 | lr 2.90e-04  -> 保存最优模型: d:\xry\yanjiusheng\1\DAMOXING\lab1\t5\checkpoints\best.pt
# epoch 35 | train 3.9554 | test 4.3531 | lr 2.89e-04  -> 保存最优模型: d:\xry\yanjiusheng\1\DAMOXING\lab1\t5\checkpoints\best.pt
# epoch 35 | train 3.9554 | test 4.3531 | lr 2.89e-04  -> 保存最优模型: d:\xry\yanjiusheng\1\DAMOXING\lab1\t5\checkpoints\best.pt
# epoch 36 | train 3.9326 | test 4.3384 | lr 2.88e-04  -> 保存最优模型: d:\xry\yanjiusheng\1\DAMOXING\lab1\t5\checkpoints\best.pt
# epoch 36 | train 3.9326 | test 4.3384 | lr 2.88e-04  -> 保存最优模型: d:\xry\yanjiusheng\1\DAMOXING\lab1\t5\checkpoints\best.pt
# epoch 37 | train 3.9078 | test 4.3408 | lr 2.87e-04
# epoch 37 | train 3.9078 | test 4.3408 | lr 2.87e-04
# epoch 38 | train 3.8853 | test 4.3262 | lr 2.86e-04  -> 保存最优模型: d:\xry\yanjiusheng\1\DAMOXING\lab1\t5\checkpoints\best.pt
# epoch 38 | train 3.8853 | test 4.3262 | lr 2.86e-04  -> 保存最优模型: d:\xry\yanjiusheng\1\DAMOXING\lab1\t5\checkpoints\best.pt
# epoch 39 | train 3.8648 | test 4.3194 | lr 2.85e-04  -> 保存最优模型: d:\xry\yanjiusheng\1\DAMOXING\lab1\t5\checkpoints\best.pt
# epoch 39 | train 3.8648 | test 4.3194 | lr 2.85e-04  -> 保存最优模型: d:\xry\yanjiusheng\1\DAMOXING\lab1\t5\checkpoints\best.pt
# epoch 40 | train 3.8427 | test 4.3170 | lr 2.84e-04  -> 保存最优模型: d:\xry\yanjiusheng\1\DAMOXING\lab1\t5\checkpoints\best.pt
# epoch 40 | train 3.8427 | test 4.3170 | lr 2.84e-04  -> 保存最优模型: d:\xry\yanjiusheng\1\DAMOXING\lab1\t5\checkpoints\best.pt
# epoch 41 | train 3.8233 | test 4.3108 | lr 2.83e-04  -> 保存最优模型: d:\xry\yanjiusheng\1\DAMOXING\lab1\t5\checkpoints\best.pt
# epoch 41 | train 3.8233 | test 4.3108 | lr 2.83e-04  -> 保存最优模型: d:\xry\yanjiusheng\1\DAMOXING\lab1\t5\checkpoints\best.pt
# epoch 42 | train 3.8027 | test 4.3069 | lr 2.82e-04  -> 保存最优模型: d:\xry\yanjiusheng\1\DAMOXING\lab1\t5\checkpoints\best.pt
# epoch 42 | train 3.8027 | test 4.3069 | lr 2.82e-04  -> 保存最优模型: d:\xry\yanjiusheng\1\DAMOXING\lab1\t5\checkpoints\best.pt
# epoch 43 | train 3.7861 | test 4.3000 | lr 2.80e-04  -> 保存最优模型: d:\xry\yanjiusheng\1\DAMOXING\lab1\t5\checkpoints\best.pt
# epoch 43 | train 3.7861 | test 4.3000 | lr 2.80e-04  -> 保存最优模型: d:\xry\yanjiusheng\1\DAMOXING\lab1\t5\checkpoints\best.pt
# epoch 44 | train 3.7662 | test 4.3010 | lr 2.79e-04
# epoch 44 | train 3.7662 | test 4.3010 | lr 2.79e-04
# epoch 45 | train 3.7442 | test 4.2981 | lr 2.78e-04  -> 保存最优模型: d:\xry\yanjiusheng\1\DAMOXING\lab1\t5\checkpoints\best.pt
# epoch 45 | train 3.7442 | test 4.2981 | lr 2.78e-04  -> 保存最优模型: d:\xry\yanjiusheng\1\DAMOXING\lab1\t5\checkpoints\best.pt
# epoch 46 | train 3.7279 | test 4.2931 | lr 2.76e-04  -> 保存最优模型: d:\xry\yanjiusheng\1\DAMOXING\lab1\t5\checkpoints\best.pt
# epoch 46 | train 3.7279 | test 4.2931 | lr 2.76e-04  -> 保存最优模型: d:\xry\yanjiusheng\1\DAMOXING\lab1\t5\checkpoints\best.pt
# epoch 47 | train 3.7108 | test 4.2927 | lr 2.75e-04  -> 保存最优模型: d:\xry\yanjiusheng\1\DAMOXING\lab1\t5\checkpoints\best.pt
# epoch 47 | train 3.7108 | test 4.2927 | lr 2.75e-04  -> 保存最优模型: d:\xry\yanjiusheng\1\DAMOXING\lab1\t5\checkpoints\best.pt
# epoch 48 | train 3.6938 | test 4.2887 | lr 2.74e-04  -> 保存最优模型: d:\xry\yanjiusheng\1\DAMOXING\lab1\t5\checkpoints\best.pt
# epoch 48 | train 3.6938 | test 4.2887 | lr 2.74e-04  -> 保存最优模型: d:\xry\yanjiusheng\1\DAMOXING\lab1\t5\checkpoints\best.pt
# epoch 49 | train 3.6756 | test 4.2862 | lr 2.72e-04  -> 保存最优模型: d:\xry\yanjiusheng\1\DAMOXING\lab1\t5\checkpoints\best.pt
# epoch 49 | train 3.6756 | test 4.2862 | lr 2.72e-04  -> 保存最优模型: d:\xry\yanjiusheng\1\DAMOXING\lab1\t5\checkpoints\best.pt
# epoch 50 | train 3.6610 | test 4.2841 | lr 2.71e-04  -> 保存最优模型: d:\xry\yanjiusheng\1\DAMOXING\lab1\t5\checkpoints\best.pt
# epoch 50 | train 3.6610 | test 4.2841 | lr 2.71e-04  -> 保存最优模型: d:\xry\yanjiusheng\1\DAMOXING\lab1\t5\checkpoints\best.pt
# epoch 51 | train 3.6415 | test 4.2830 | lr 2.69e-04  -> 保存最优模型: d:\xry\yanjiusheng\1\DAMOXING\lab1\t5\checkpoints\best.pt
# epoch 51 | train 3.6415 | test 4.2830 | lr 2.69e-04  -> 保存最优模型: d:\xry\yanjiusheng\1\DAMOXING\lab1\t5\checkpoints\best.pt
# epoch 52 | train 3.6240 | test 4.2808 | lr 2.68e-04  -> 保存最优模型: d:\xry\yanjiusheng\1\DAMOXING\lab1\t5\checkpoints\best.pt
# epoch 52 | train 3.6240 | test 4.2808 | lr 2.68e-04  -> 保存最优模型: d:\xry\yanjiusheng\1\DAMOXING\lab1\t5\checkpoints\best.pt
# epoch 53 | train 3.6105 | test 4.2814 | lr 2.66e-04
# epoch 53 | train 3.6105 | test 4.2814 | lr 2.66e-04
# epoch 54 | train 3.5984 | test 4.2829 | lr 2.65e-04
# epoch 54 | train 3.5984 | test 4.2829 | lr 2.65e-04
# epoch 55 | train 3.5842 | test 4.2785 | lr 2.63e-04  -> 保存最优模型: d:\xry\yanjiusheng\1\DAMOXING\lab1\t5\checkpoints\best.pt
# epoch 55 | train 3.5842 | test 4.2785 | lr 2.63e-04  -> 保存最优模型: d:\xry\yanjiusheng\1\DAMOXING\lab1\t5\checkpoints\best.pt
# epoch 56 | train 3.5673 | test 4.2791 | lr 2.61e-04
# epoch 56 | train 3.5673 | test 4.2791 | lr 2.61e-04
# epoch 57 | train 3.5550 | test 4.2829 | lr 2.60e-04
# epoch 57 | train 3.5550 | test 4.2829 | lr 2.60e-04
# epoch 58 | train 3.5382 | test 4.2819 | lr 2.58e-04
# epoch 58 | train 3.5382 | test 4.2819 | lr 2.58e-04
# epoch 59 | train 3.5265 | test 4.2802 | lr 2.56e-04
# epoch 59 | train 3.5265 | test 4.2802 | lr 2.56e-04
# epoch 60 | train 3.5121 | test 4.2832 | lr 2.54e-04
# epoch 60 | train 3.5121 | test 4.2832 | lr 2.54e-04
# epoch 61 | train 3.4958 | test 4.2880 | lr 2.52e-04
# epoch 61 | train 3.4958 | test 4.2880 | lr 2.52e-04
# epoch 62 | train 3.4853 | test 4.2838 | lr 2.51e-04
# epoch 62 | train 3.4853 | test 4.2838 | lr 2.51e-04
# epoch 63 | train 3.4706 | test 4.2816 | lr 2.49e-04
# epoch 63 | train 3.4706 | test 4.2816 | lr 2.49e-04
# epoch 64 | train 3.4624 | test 4.2853 | lr 2.47e-04
# epoch 64 | train 3.4624 | test 4.2853 | lr 2.47e-04
# epoch 65 | train 3.4484 | test 4.2892 | lr 2.45e-04
# epoch 65 | train 3.4484 | test 4.2892 | lr 2.45e-04
# epoch 66 | train 3.4329 | test 4.2884 | lr 2.43e-04
# epoch 66 | train 3.4329 | test 4.2884 | lr 2.43e-04
# epoch 67 | train 3.4248 | test 4.2906 | lr 2.41e-04
# epoch 67 | train 3.4248 | test 4.2906 | lr 2.41e-04
# epoch 68 | train 3.4124 | test 4.2920 | lr 2.39e-04
# epoch 68 | train 3.4124 | test 4.2920 | lr 2.39e-04
# epoch 69 | train 3.3990 | test 4.2889 | lr 2.37e-04
# epoch 69 | train 3.3990 | test 4.2889 | lr 2.37e-04
# epoch 70 | train 3.3898 | test 4.2918 | lr 2.35e-04
# epoch 70 | train 3.3898 | test 4.2918 | lr 2.35e-04
# epoch 71 | train 3.3776 | test 4.2977 | lr 2.33e-04
# epoch 71 | train 3.3776 | test 4.2977 | lr 2.33e-04
# epoch 72 | train 3.3665 | test 4.2990 | lr 2.31e-04
# epoch 72 | train 3.3665 | test 4.2990 | lr 2.31e-04
# epoch 73 | train 3.3582 | test 4.3019 | lr 2.29e-04
# epoch 73 | train 3.3582 | test 4.3019 | lr 2.29e-04
# epoch 74 | train 3.3454 | test 4.3011 | lr 2.26e-04
# epoch 74 | train 3.3454 | test 4.3011 | lr 2.26e-04
# epoch 75 | train 3.3347 | test 4.3039 | lr 2.24e-04
# epoch 75 | train 3.3347 | test 4.3039 | lr 2.24e-04
# epoch 76 | train 3.3265 | test 4.3081 | lr 2.22e-04
# epoch 76 | train 3.3265 | test 4.3081 | lr 2.22e-04
# epoch 77 | train 3.3166 | test 4.3055 | lr 2.20e-04
# epoch 77 | train 3.3166 | test 4.3055 | lr 2.20e-04
# epoch 78 | train 3.3070 | test 4.3092 | lr 2.18e-04
# epoch 78 | train 3.3070 | test 4.3092 | lr 2.18e-04
# epoch 79 | train 3.2994 | test 4.3124 | lr 2.15e-04
# epoch 79 | train 3.2994 | test 4.3124 | lr 2.15e-04
# epoch 80 | train 3.2902 | test 4.3182 | lr 2.13e-04
# epoch 80 | train 3.2902 | test 4.3182 | lr 2.13e-04
# epoch 81 | train 3.2800 | test 4.3189 | lr 2.11e-04
# epoch 81 | train 3.2800 | test 4.3189 | lr 2.11e-04
# epoch 82 | train 3.2680 | test 4.3218 | lr 2.09e-04
# epoch 82 | train 3.2680 | test 4.3218 | lr 2.09e-04
# epoch 83 | train 3.2576 | test 4.3248 | lr 2.06e-04
# epoch 83 | train 3.2576 | test 4.3248 | lr 2.06e-04
# epoch 84 | train 3.2518 | test 4.3280 | lr 2.04e-04
# epoch 84 | train 3.2518 | test 4.3280 | lr 2.04e-04
# epoch 85 | train 3.2419 | test 4.3272 | lr 2.02e-04
# epoch 85 | train 3.2419 | test 4.3272 | lr 2.02e-04
# epoch 86 | train 3.2353 | test 4.3303 | lr 1.99e-04
# epoch 86 | train 3.2353 | test 4.3303 | lr 1.99e-04
# epoch 87 | train 3.2257 | test 4.3326 | lr 1.97e-04
# epoch 87 | train 3.2257 | test 4.3326 | lr 1.97e-04
# epoch 88 | train 3.2173 | test 4.3372 | lr 1.94e-04
# epoch 88 | train 3.2173 | test 4.3372 | lr 1.94e-04
# epoch 89 | train 3.2094 | test 4.3378 | lr 1.92e-04
# epoch 89 | train 3.2094 | test 4.3378 | lr 1.92e-04
# epoch 90 | train 3.1999 | test 4.3423 | lr 1.90e-04
# epoch 90 | train 3.1999 | test 4.3423 | lr 1.90e-04
# epoch 91 | train 3.1934 | test 4.3437 | lr 1.87e-04
# epoch 91 | train 3.1934 | test 4.3437 | lr 1.87e-04
# epoch 92 | train 3.1868 | test 4.3440 | lr 1.85e-04
# epoch 92 | train 3.1868 | test 4.3440 | lr 1.85e-04
# epoch 93 | train 3.1788 | test 4.3463 | lr 1.82e-04
# epoch 93 | train 3.1788 | test 4.3463 | lr 1.82e-04
# epoch 94 | train 3.1729 | test 4.3470 | lr 1.80e-04
# epoch 94 | train 3.1729 | test 4.3470 | lr 1.80e-04
# epoch 95 | train 3.1642 | test 4.3492 | lr 1.77e-04
# epoch 95 | train 3.1642 | test 4.3492 | lr 1.77e-04
# epoch 96 | train 3.1579 | test 4.3534 | lr 1.75e-04
# epoch 96 | train 3.1579 | test 4.3534 | lr 1.75e-04
# epoch 97 | train 3.1506 | test 4.3587 | lr 1.72e-04
# epoch 97 | train 3.1506 | test 4.3587 | lr 1.72e-04
# epoch 98 | train 3.1415 | test 4.3585 | lr 1.70e-04
# epoch 98 | train 3.1415 | test 4.3585 | lr 1.70e-04
# epoch 99 | train 3.1357 | test 4.3634 | lr 1.68e-04
# epoch 99 | train 3.1357 | test 4.3634 | lr 1.68e-04
# epoch 100 | train 3.1319 | test 4.3621 | lr 1.65e-04
# epoch 100 | train 3.1319 | test 4.3621 | lr 1.65e-04
# epoch 101 | train 3.1243 | test 4.3652 | lr 1.63e-04
# epoch 101 | train 3.1243 | test 4.3652 | lr 1.63e-04
# epoch 102 | train 3.1163 | test 4.3664 | lr 1.60e-04
# epoch 102 | train 3.1163 | test 4.3664 | lr 1.60e-04
# epoch 103 | train 3.1100 | test 4.3697 | lr 1.58e-04
# epoch 103 | train 3.1100 | test 4.3697 | lr 1.58e-04
# epoch 104 | train 3.1028 | test 4.3729 | lr 1.55e-04
# epoch 104 | train 3.1028 | test 4.3729 | lr 1.55e-04
# epoch 105 | train 3.0997 | test 4.3763 | lr 1.53e-04
# epoch 105 | train 3.0997 | test 4.3763 | lr 1.53e-04
# epoch 106 | train 3.0925 | test 4.3777 | lr 1.50e-04
# epoch 106 | train 3.0925 | test 4.3777 | lr 1.50e-04
# epoch 107 | train 3.0875 | test 4.3789 | lr 1.47e-04
# epoch 107 | train 3.0875 | test 4.3789 | lr 1.47e-04
# epoch 108 | train 3.0780 | test 4.3836 | lr 1.45e-04
# epoch 108 | train 3.0780 | test 4.3836 | lr 1.45e-04
# epoch 109 | train 3.0749 | test 4.3837 | lr 1.42e-04
# epoch 109 | train 3.0749 | test 4.3837 | lr 1.42e-04
# epoch 110 | train 3.0694 | test 4.3838 | lr 1.40e-04
# epoch 110 | train 3.0694 | test 4.3838 | lr 1.40e-04
# epoch 111 | train 3.0672 | test 4.3860 | lr 1.37e-04
# epoch 111 | train 3.0672 | test 4.3860 | lr 1.37e-04
# epoch 112 | train 3.0596 | test 4.3892 | lr 1.35e-04
# epoch 112 | train 3.0596 | test 4.3892 | lr 1.35e-04
# epoch 113 | train 3.0579 | test 4.3899 | lr 1.32e-04
# epoch 113 | train 3.0579 | test 4.3899 | lr 1.32e-04
# epoch 114 | train 3.0482 | test 4.3940 | lr 1.30e-04
# epoch 114 | train 3.0482 | test 4.3940 | lr 1.30e-04
# epoch 115 | train 3.0422 | test 4.3947 | lr 1.28e-04
# epoch 115 | train 3.0422 | test 4.3947 | lr 1.28e-04
# epoch 116 | train 3.0401 | test 4.4027 | lr 1.25e-04
# epoch 116 | train 3.0401 | test 4.4027 | lr 1.25e-04
# epoch 117 | train 3.0344 | test 4.3983 | lr 1.23e-04
# epoch 117 | train 3.0344 | test 4.3983 | lr 1.23e-04
# epoch 118 | train 3.0306 | test 4.4022 | lr 1.20e-04
# epoch 118 | train 3.0306 | test 4.4022 | lr 1.20e-04
# epoch 119 | train 3.0289 | test 4.4029 | lr 1.18e-04
# epoch 119 | train 3.0289 | test 4.4029 | lr 1.18e-04
# epoch 120 | train 3.0207 | test 4.4051 | lr 1.15e-04
# epoch 120 | train 3.0207 | test 4.4051 | lr 1.15e-04
# epoch 121 | train 3.0167 | test 4.4104 | lr 1.13e-04
# epoch 121 | train 3.0167 | test 4.4104 | lr 1.13e-04
# epoch 122 | train 3.0101 | test 4.4079 | lr 1.10e-04
# epoch 122 | train 3.0101 | test 4.4079 | lr 1.10e-04
# epoch 123 | train 3.0112 | test 4.4108 | lr 1.08e-04
# epoch 123 | train 3.0112 | test 4.4108 | lr 1.08e-04
# epoch 124 | train 3.0081 | test 4.4116 | lr 1.06e-04
# epoch 124 | train 3.0081 | test 4.4116 | lr 1.06e-04
# epoch 125 | train 3.0017 | test 4.4134 | lr 1.03e-04
# epoch 125 | train 3.0017 | test 4.4134 | lr 1.03e-04
# epoch 126 | train 2.9980 | test 4.4157 | lr 1.01e-04
# epoch 126 | train 2.9980 | test 4.4157 | lr 1.01e-04
# epoch 127 | train 2.9957 | test 4.4157 | lr 9.84e-05
# epoch 127 | train 2.9957 | test 4.4157 | lr 9.84e-05
# epoch 128 | train 2.9895 | test 4.4164 | lr 9.61e-05
# epoch 128 | train 2.9895 | test 4.4164 | lr 9.61e-05
# epoch 129 | train 2.9882 | test 4.4190 | lr 9.38e-05
# epoch 129 | train 2.9882 | test 4.4190 | lr 9.38e-05
# epoch 130 | train 2.9866 | test 4.4229 | lr 9.14e-05
# epoch 130 | train 2.9866 | test 4.4229 | lr 9.14e-05
# epoch 131 | train 2.9799 | test 4.4241 | lr 8.91e-05
# epoch 131 | train 2.9799 | test 4.4241 | lr 8.91e-05
# epoch 132 | train 2.9760 | test 4.4237 | lr 8.69e-05
# epoch 132 | train 2.9760 | test 4.4237 | lr 8.69e-05
# epoch 133 | train 2.9713 | test 4.4247 | lr 8.46e-05
# epoch 133 | train 2.9713 | test 4.4247 | lr 8.46e-05
# epoch 134 | train 2.9686 | test 4.4256 | lr 8.23e-05
# epoch 134 | train 2.9686 | test 4.4256 | lr 8.23e-05
# epoch 135 | train 2.9651 | test 4.4277 | lr 8.01e-05
# epoch 135 | train 2.9651 | test 4.4277 | lr 8.01e-05
# epoch 136 | train 2.9629 | test 4.4271 | lr 7.79e-05
# epoch 136 | train 2.9629 | test 4.4271 | lr 7.79e-05
# epoch 137 | train 2.9608 | test 4.4283 | lr 7.57e-05
# epoch 137 | train 2.9608 | test 4.4283 | lr 7.57e-05
# epoch 138 | train 2.9605 | test 4.4321 | lr 7.36e-05
# epoch 138 | train 2.9605 | test 4.4321 | lr 7.36e-05
# epoch 139 | train 2.9529 | test 4.4324 | lr 7.14e-05
# epoch 139 | train 2.9529 | test 4.4324 | lr 7.14e-05
# epoch 140 | train 2.9516 | test 4.4351 | lr 6.93e-05
# epoch 140 | train 2.9516 | test 4.4351 | lr 6.93e-05
# epoch 141 | train 2.9527 | test 4.4342 | lr 6.72e-05
# epoch 141 | train 2.9527 | test 4.4342 | lr 6.72e-05
# epoch 142 | train 2.9454 | test 4.4370 | lr 6.51e-05
# epoch 142 | train 2.9454 | test 4.4370 | lr 6.51e-05
# epoch 143 | train 2.9465 | test 4.4356 | lr 6.31e-05
# epoch 143 | train 2.9465 | test 4.4356 | lr 6.31e-05
# epoch 144 | train 2.9438 | test 4.4364 | lr 6.10e-05
# epoch 144 | train 2.9438 | test 4.4364 | lr 6.10e-05
# epoch 145 | train 2.9446 | test 4.4387 | lr 5.90e-05
# epoch 145 | train 2.9446 | test 4.4387 | lr 5.90e-05
# epoch 146 | train 2.9394 | test 4.4397 | lr 5.70e-05
# epoch 146 | train 2.9394 | test 4.4397 | lr 5.70e-05
# epoch 147 | train 2.9358 | test 4.4412 | lr 5.51e-05
# epoch 147 | train 2.9358 | test 4.4412 | lr 5.51e-05
# epoch 148 | train 2.9330 | test 4.4408 | lr 5.32e-05
# epoch 148 | train 2.9330 | test 4.4408 | lr 5.32e-05
# epoch 149 | train 2.9314 | test 4.4427 | lr 5.13e-05
# epoch 149 | train 2.9314 | test 4.4427 | lr 5.13e-05
# epoch 150 | train 2.9303 | test 4.4433 | lr 4.94e-05
# epoch 150 | train 2.9303 | test 4.4433 | lr 4.94e-05
# epoch 151 | train 2.9280 | test 4.4445 | lr 4.75e-05
# epoch 151 | train 2.9280 | test 4.4445 | lr 4.75e-05
# epoch 152 | train 2.9262 | test 4.4479 | lr 4.57e-05
# epoch 152 | train 2.9262 | test 4.4479 | lr 4.57e-05
# epoch 153 | train 2.9270 | test 4.4474 | lr 4.39e-05
# epoch 153 | train 2.9270 | test 4.4474 | lr 4.39e-05
# epoch 154 | train 2.9230 | test 4.4473 | lr 4.22e-05
# epoch 154 | train 2.9230 | test 4.4473 | lr 4.22e-05
# epoch 155 | train 2.9226 | test 4.4468 | lr 4.04e-05
# epoch 155 | train 2.9226 | test 4.4468 | lr 4.04e-05
# epoch 156 | train 2.9224 | test 4.4488 | lr 3.88e-05
# epoch 156 | train 2.9224 | test 4.4488 | lr 3.88e-05
# epoch 157 | train 2.9218 | test 4.4493 | lr 3.71e-05
# epoch 157 | train 2.9218 | test 4.4493 | lr 3.71e-05
# epoch 158 | train 2.9137 | test 4.4495 | lr 3.55e-05
# epoch 158 | train 2.9137 | test 4.4495 | lr 3.55e-05
# epoch 159 | train 2.9186 | test 4.4510 | lr 3.38e-05
# epoch 159 | train 2.9186 | test 4.4510 | lr 3.38e-05
# epoch 160 | train 2.9182 | test 4.4511 | lr 3.23e-05
# epoch 160 | train 2.9182 | test 4.4511 | lr 3.23e-05
# epoch 161 | train 2.9129 | test 4.4515 | lr 3.07e-05
# epoch 161 | train 2.9129 | test 4.4515 | lr 3.07e-05
# epoch 162 | train 2.9152 | test 4.4519 | lr 2.92e-05
# epoch 162 | train 2.9152 | test 4.4519 | lr 2.92e-05
# epoch 163 | train 2.9139 | test 4.4520 | lr 2.78e-05
# epoch 163 | train 2.9139 | test 4.4520 | lr 2.78e-05
# epoch 164 | train 2.9113 | test 4.4523 | lr 2.63e-05
# epoch 164 | train 2.9113 | test 4.4523 | lr 2.63e-05
# epoch 165 | train 2.9097 | test 4.4520 | lr 2.49e-05
# epoch 165 | train 2.9097 | test 4.4520 | lr 2.49e-05
# epoch 166 | train 2.9095 | test 4.4530 | lr 2.36e-05
# epoch 166 | train 2.9095 | test 4.4530 | lr 2.36e-05
# epoch 167 | train 2.9070 | test 4.4532 | lr 2.22e-05
# epoch 167 | train 2.9070 | test 4.4532 | lr 2.22e-05
# epoch 168 | train 2.9035 | test 4.4531 | lr 2.09e-05
# epoch 168 | train 2.9035 | test 4.4531 | lr 2.09e-05
# epoch 169 | train 2.9005 | test 4.4538 | lr 1.97e-05
# epoch 169 | train 2.9005 | test 4.4538 | lr 1.97e-05
# epoch 170 | train 2.9045 | test 4.4546 | lr 1.85e-05
# epoch 170 | train 2.9045 | test 4.4546 | lr 1.85e-05
# epoch 171 | train 2.9046 | test 4.4548 | lr 1.73e-05
# epoch 171 | train 2.9046 | test 4.4548 | lr 1.73e-05
# epoch 172 | train 2.9019 | test 4.4558 | lr 1.61e-05
# epoch 172 | train 2.9019 | test 4.4558 | lr 1.61e-05
# epoch 173 | train 2.9010 | test 4.4552 | lr 1.50e-05
# epoch 173 | train 2.9010 | test 4.4552 | lr 1.50e-05
# epoch 174 | train 2.9002 | test 4.4558 | lr 1.39e-05
# epoch 174 | train 2.9002 | test 4.4558 | lr 1.39e-05
# epoch 175 | train 2.8965 | test 4.4561 | lr 1.29e-05
# epoch 175 | train 2.8965 | test 4.4561 | lr 1.29e-05
# epoch 176 | train 2.8969 | test 4.4564 | lr 1.19e-05
# epoch 176 | train 2.8969 | test 4.4564 | lr 1.19e-05
# epoch 177 | train 2.9006 | test 4.4565 | lr 1.09e-05
# epoch 177 | train 2.9006 | test 4.4565 | lr 1.09e-05
# epoch 178 | train 2.9020 | test 4.4569 | lr 1.00e-05
# epoch 178 | train 2.9020 | test 4.4569 | lr 1.00e-05
# epoch 179 | train 2.8979 | test 4.4566 | lr 9.14e-06
# epoch 179 | train 2.8979 | test 4.4566 | lr 9.14e-06
# epoch 180 | train 2.8986 | test 4.4570 | lr 8.30e-06
# epoch 180 | train 2.8986 | test 4.4570 | lr 8.30e-06
# epoch 181 | train 2.8974 | test 4.4573 | lr 7.50e-06
# epoch 181 | train 2.8974 | test 4.4573 | lr 7.50e-06
# epoch 182 | train 2.8983 | test 4.4574 | lr 6.73e-06
# epoch 182 | train 2.8983 | test 4.4574 | lr 6.73e-06
# epoch 183 | train 2.8992 | test 4.4575 | lr 6.01e-06
# epoch 183 | train 2.8992 | test 4.4575 | lr 6.01e-06
# epoch 184 | train 2.9004 | test 4.4578 | lr 5.33e-06
# epoch 184 | train 2.9004 | test 4.4578 | lr 5.33e-06
# epoch 185 | train 2.8965 | test 4.4578 | lr 4.69e-06
# epoch 185 | train 2.8965 | test 4.4578 | lr 4.69e-06
# epoch 186 | train 2.8944 | test 4.4581 | lr 4.09e-06
# epoch 186 | train 2.8944 | test 4.4581 | lr 4.09e-06
# epoch 187 | train 2.8995 | test 4.4580 | lr 3.53e-06
# epoch 187 | train 2.8995 | test 4.4580 | lr 3.53e-06
# epoch 188 | train 2.8962 | test 4.4582 | lr 3.01e-06
# epoch 188 | train 2.8962 | test 4.4582 | lr 3.01e-06
# epoch 189 | train 2.8955 | test 4.4583 | lr 2.53e-06
# epoch 189 | train 2.8955 | test 4.4583 | lr 2.53e-06
# epoch 190 | train 2.8937 | test 4.4584 | lr 2.09e-06
# epoch 190 | train 2.8937 | test 4.4584 | lr 2.09e-06
# epoch 191 | train 2.8982 | test 4.4584 | lr 1.69e-06
# epoch 191 | train 2.8982 | test 4.4584 | lr 1.69e-06
# epoch 192 | train 2.8974 | test 4.4584 | lr 1.34e-06
# epoch 192 | train 2.8974 | test 4.4584 | lr 1.34e-06
# epoch 193 | train 2.8999 | test 4.4583 | lr 1.03e-06
# epoch 193 | train 2.8999 | test 4.4583 | lr 1.03e-06
# epoch 194 | train 2.8961 | test 4.4583 | lr 7.53e-07
# epoch 194 | train 2.8961 | test 4.4583 | lr 7.53e-07
# epoch 195 | train 2.8961 | test 4.4583 | lr 5.23e-07
# epoch 195 | train 2.8961 | test 4.4583 | lr 5.23e-07
# epoch 196 | train 2.8958 | test 4.4583 | lr 3.35e-07
# epoch 196 | train 2.8958 | test 4.4583 | lr 3.35e-07
# epoch 197 | train 2.8954 | test 4.4583 | lr 1.88e-07
# epoch 197 | train 2.8954 | test 4.4583 | lr 1.88e-07
# epoch 198 | train 2.8959 | test 4.4584 | lr 8.38e-08
# epoch 198 | train 2.8959 | test 4.4584 | lr 8.38e-08
# epoch 199 | train 2.8954 | test 4.4584 | lr 2.09e-08
# epoch 199 | train 2.8954 | test 4.4584 | lr 2.09e-08
# epoch 200 | train 2.8946 | test 4.4583 | lr 0.00e+00
# epoch 200 | train 2.8946 | test 4.4583 | lr 0.00e+00

# %%
# 可视化训练曲线（Train/Test Loss 与 LR）
import matplotlib.pyplot as plt

fig, axes = plt.subplots(1, 2, figsize=(13, 4))
epochs = range(1, len(train_losses)+1)
axes[0].plot(epochs, train_losses, marker='o', markersize=3, label='Train Loss')
axes[0].plot(epochs, test_losses, marker='s', markersize=3, label='Test Loss')
axes[0].set_title(f'Loss per Epoch (mode={schedule_mode})')
axes[0].set_xlabel('Epoch')
axes[0].set_ylabel('Loss')
axes[0].grid(alpha=0.3)
axes[0].legend()

axes[1].plot(lrs, linewidth=1)
axes[1].set_title('Learning Rate per Step')
axes[1].set_xlabel('Step')
axes[1].set_ylabel('LR')
axes[1].grid(alpha=0.3)
plt.tight_layout()
plt.show()

# %%
# （可选）加载检查点再进行推理
# 将 load_best 设为 True 可加载最优模型权重
load_best = True
ckpt_path = best_ckpt if load_best else last_ckpt
if ckpt_path.exists():
    ep, best = load_checkpoint(ckpt_path, model, optimizer=None)
    print(f"已加载检查点: {ckpt_path} | epoch={ep} | best_loss={best}")
else:
    print(f"未找到检查点: {ckpt_path}")
# Out:
# [load_checkpoint] 恢复 epoch=55 best_loss=4.2784588904607865 global_step=2585
# 已加载检查点: d:\xry\yanjiusheng\1\DAMOXING\lab1\t5\checkpoints\best.pt | epoch=55 | best_loss=4.2784588904607865

# %%
tests = [
    "What was the result",
    "It's a crisis",
    "how are you",
    "see you",
    "Sound familiar? Right",
    "Thank you very much"
 ]
for i, s in enumerate(tests, 1):
    zh = greedy_decode(model, s)
    print(f"这是第{i}条输出：{s} -> {zh}")
# Out:
# 这是第1条输出：What was the result -> 这是什么？
# 这是第2条输出：It's a crisis -> 这是一个问题。
# 这是第3条输出：how are you -> 你们如何？
# 这是第4条输出：see you -> 你看到了。
# 这是第5条输出：Sound familiar? Right -> 在这里有什么？
# 这是第6条输出：Thank you very much -> 谢谢。
